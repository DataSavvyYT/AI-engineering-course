# %% [markdown]
# <a href="https://colab.research.google.com/github/DataSavvyYT/AI-engineering-course/blob/main/03_llm_memory/01_llm_memory_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Install the Google AI library
# !pip install -q -U google-generativeai

# %%
import google.generativeai as genai
import os

# %%
from google.colab import userdata
userdata.get('secretName')

# %%
# 2. Setup - REPLACE 'YOUR_API_KEY' WITH YOUR ACTUAL KEY
os.environ["GOOGLE_API_KEY"] = "YOUR_API_KEY"
genai.configure(api_key=os.environ["GOOGLE_API_KEY"])
