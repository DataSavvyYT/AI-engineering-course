# %% [markdown]
# <a href="https://colab.research.google.com/github/DataSavvyYT/AI-engineering-course/blob/main/03_llm_memory/02_add_memory_to_llm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Install the Google AI library
# !pip install -q -U google-generativeai

# %%
import google.generativeai as genai
import os

# %%
from google.colab import userdata
GEMINI_API_KEY=userdata.get('GEMINI_API_KEY2')

# %%
# 2. Setup - REPLACE 'GEMINI_API_KEY' WITH YOUR ACTUAL KEY
os.environ["GOOGLE_API_KEY"] = "GEMINI_API_KEY"
genai.configure(api_key=GEMINI_API_KEY)

# %%
# 3. Initialize the Model
model = genai.GenerativeModel('gemini-2.5-flash')

# %%
print("--- Interaction 1: Teaching the model a fact ---")
# We tell the model a specific fact (a secret number)
prompt_1 = "Hi! Remember this secret number: 998877. Do not forget it."
response_1 = model.generate_content(prompt_1)
print(f"Me: {prompt_1}")
print(f"Gemini: {response_1.text}")
# Out:
# --- Interaction 1: Teaching the model a fact ---
# Me: Hi! Remember this secret number: 998877. Do not forget it.
# Gemini: Got it! I will remember 998877.

# %%
print("\n--- Interaction 2: Testing Memory ---")
# We ask the model to recall the fact in a NEW call
prompt_2 = "What is the secret number I just told you?"
response_2 = model.generate_content(prompt_2)
print(f"Me: {prompt_2}")
print(f"Gemini: {response_2.text}")
# Out:
# --- Interaction 2: Testing Memory ---
# Me: What is the secret number I just told you?
# Gemini: You didn't tell me a secret number! I don't have any previous information from you about one.
#
# If you'd like to tell me one, I'd be happy to keep it in mind for this conversation! 😉

# %% [markdown]
# Notice that in Interaction 2, Gemini likely said it doesn't know or asked for context.
# This proves the model itself has no memory; it treats every call as a brand new conversation.

# %%
print("\n--- Interaction 3: Demonstrating memory with a chat session ---")

# Define prompts for this interaction, in case they weren't defined earlier
prompt_1 = "Hi! Remember this secret number: 998877. Do not forget it."
prompt_2 = "What is the secret number I just told you?"

# Start a chat session
chat = model.start_chat(history=[])

# Send the first message to the chat session
print(f"Me: {prompt_1}")
response_chat_1 = chat.send_message(prompt_1)
print(f"Gemini: {response_chat_1.text}")

# Send the second message, which should now recall the secret number
print(f"Me: {prompt_2}")
response_chat_2 = chat.send_message(prompt_2)
print(f"Gemini: {response_chat_2.text}")
# Out:
# --- Interaction 3: Demonstrating memory with a chat session ---
# Me: Hi! Remember this secret number: 998877. Do not forget it.
# Gemini: Okay, I've noted that down. Your secret number is 998877. I will remember it.
# Me: What is the secret number I just told you?
# Gemini: The secret number you just told me is 998877.
