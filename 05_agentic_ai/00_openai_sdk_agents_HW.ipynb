# %% [markdown]
# <a href="https://colab.research.google.com/github/DataSavvyYT/AI-engineering-course/blob/main/05_agentic_ai/00_openai_sdk_agents_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q openai-agents
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.3/238.3 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.7/150.7 kB 6.1 MB/s eta 0:00:00

# %%
from agents import Agent, Runner

# %%
from google.colab import userdata
import os
from agents import Agent, Runner, RunConfig, OpenAIProvider

# Ensure the API key is available
OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')
os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY

# %%
# Initialize the Agent with the specified model
agent = Agent(name="Assistant", instructions="You are a helpful assistant", model="gpt-4o-mini")

# %%
result = await Runner.run(agent, "write a python program on fibonacci")
print(result.final_output)
# Out:
# Sure! Below is a simple Python program that generates Fibonacci numbers. The program includes a function to compute Fibonacci numbers both iteratively and recursively, along with a main section to run the program.
#
# ### Fibonacci Program in Python
#
# ```python
# def fibonacci_iterative(n):
#     """Return the nth Fibonacci number using an iterative approach."""
#     a, b = 0, 1
#     for _ in range(n):
#         a, b = b, a + b
#     return a
#
# def fibonacci_recursive(n):
#     """Return the nth Fibonacci number using a recursive approach."""
#     if n <= 0:
#         return 0
#     elif n == 1:
#         return 1
#     else:
#         return fibonacci_recursive(n - 1) + fibonacci_recursive(n - 2)
#
# def main():
#     n = int(input("Enter the position of Fibonacci sequence (non-negative integer): "))
#
#     if n < 0:
#         print("Please enter a non-negative integer.")
#         return
#
#     # Display Fibonacci number using iterative approach
# ...
